# %%
import flickr_api
import imageio
import keras
import urllib2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
user = flickr_api.

# %%
REST_ENDPOINT = 'https://api.flickr.com/services/rest/'

# %%
photos = flickr_api.Photo.search(tags='skyline boston', sort='relevance', content_type=1, page=1)

# %%
for p in photos[0:5]:
    url = p.getSizes()['Small']['source']
    img = urllib2.urlopen(url).read()
    img = imageio.imread(img)

    pad_height = 242 - img.shape[0]
    pad_width = 242 - img.shape[1]
    
    img = np.pad(img, ((pad_height/2,pad_height/2), (0,0), (0,0)), mode='constant')
    img = np.pad(img, ((0,0), (pad_width/2,pad_width/2), (0,0)), mode='constant')
    img = img[:240,:240]
# Out:
# (240, 240, 3)
# (240, 240, 3)
# (240, 240, 3)
# (240, 240, 3)
# (240, 240, 3)

# %%
photos[0]
# Out:
# Photo(id='28036795104', title='Sunset Rainclouds O...)

# %%
p0 = photos[0]

# %%
url = p0.getSizes()['Small']['source']

# %%
img = urllib2.urlopen(url)

# %%
np.loadtxt(img, unpack=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-b7c087335d3d> in <module>()
# ----> 1 np.loadtxt(img, unpack=True)
#
# /home/d/anaconda2/envs/KERAS/lib/python2.7/site-packages/numpy/lib/npyio.pyc in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#    1022
#    1023             # Convert each value according to its column and store
# -> 1024             items = [conv(val) for (conv, val) in zip(converters, vals)]
#    1025             # Then pack it according to the dtype's nesting
#    1026             items = pack_items(items, packing)
#
# /home/d/anaconda2/envs/KERAS/lib/python2.7/site-packages/numpy/lib/npyio.pyc in floatconv(x)
#     723         if b'0x' in x:
#     724             return float.fromhex(asstr(x))
# --> 725         return float(x)
#     726
#     727     typ = dtype.type
#
# ...

# %%
img = imageio.imread(img.read())

# %%
imshow(img)
