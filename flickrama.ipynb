# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2

import time

import flickrama as F
# Out:
# Populating the interactive namespace from numpy and matplotlib
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
d = F.Data('boston skyline')

# %%
t0 = time.time()
batch = d.next_batch(1)
print time.time() - t0
# Out:
# using page 1
# use cache at least once
# 1.09433579445

# %%
t0 = time.time()
batch = d.next_batch(1)
print time.time() - t0
# Out:
# using page 1
# use cache at least once
# 0.521197795868

# %%
imshow(batch[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-419682451f26> in <module>()
# ----> 1 imshow(batch[3])
#
# IndexError: list index out of range

# %%
batch2 = d.next_batch()

# %%
imshow(batch2[90])

# %%
4000 / 100
# Out:
# 40
