# %%
# %pylab inline
# %load_ext autoreload
# %autoreload 2

import time

import flickrama as F
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
d = F.Data('boston skyline', size=(74,74), flickr_size='Square', batch_size=100, grayscale=True, normalize=True, expand=True, downsample=True)

# %%
for i in range(10):
    t0 = time.time()
    batch = d.next()
    print i, len(batch), time.time() - t0
# Out:
# using page 1
# 0 100 45.0234351158
# using page 2
# 1 100 44.0516200066
# using page 3
# 2 100 39.602602005
# using page 4
# 3 100 44.2426860332
# using page 5
# 4 99 46.7781879902
# using page 6
# 5 99 44.2280819416
# using page 7
# 6 100 52.5308659077
# using page 8
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-20f461347fd9> in <module>()
#       1 for i in range(10):
#       2     t0 = time.time()
# ----> 3     batch = d.next()
#       4     print i, len(batch), time.time() - t0
#
# /home/d/Projects/ILYBOS/flickrama/data.pyc in next(self, page)
#      74
#      75         url = p.getSizes()[self._flickr_size]['source']
# ---> 76         img = urllib2.urlopen(url).read()
#      77         img = imageio.imread(img)
#      78
#
# /home/d/anaconda2/envs/KERAS/lib/python2.7/urllib2.pyc in urlopen(url, data, timeout, cafile, capath, cadefault, context)
# ...

# %%
d = F.Data('boston skyline', size=(74,74), flickr_size='Square', batch_size=5, grayscale=True, normalize=True, downsample=True)

# %%
t0 = time.time()
batch = d.next()
print time.time() - t0
# Out:
# using page 1
# 2.1916680336

# %%
batch[4].min()
# Out:
# -1.0

# %%
imshow(batch[5], cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-11-5b8aceeb47b6> in <module>()
# ----> 1 imshow(batch[5], cmap='gray')
#
# IndexError: list index out of range

# %%
import scipy.misc
a = scipy.misc.imresize(batch[0], (28,28))
imshow(a, cmap='gray')

# %%
imshow(batch[3], cmap='gray')

# %%
imshow(np.resize(batch[0], (28,28)), cmap='gray')

# %%
for l in batch:
    print l.shape
# Out:
# (75, 75)
# (75, 75)
# (75, 75)
# (75, 75)
# (75, 75)

# %%
batch2 = d.next_batch()

# %%
imshow(batch2[90])

# %%
4000 / 100
# Out:
# 40
